# %%
import pandas as pd
df = pd.read_csv("AmesHousing.csv")
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
df.loc[:, ['Gr Liv Area', 'Bedroom AbvGr', 'Full Bath', 'Year Built', 'SalePrice']]
# Out:
#       Gr Liv Area  Bedroom AbvGr  Full Bath  Year Built  SalePrice
# 0            1656              3          1        1960     215000
# 1             896              2          1        1961     105000
# 2            1329              3          1        1958     172000
# 3            2110              3          2        1968     244000
# 4            1629              3          2        1997     189900
# ...           ...            ...        ...         ...        ...
# 2925         1003              3          1        1984     142500
# 2926          902              2          1        1983     131000
# 2927          970              3          1        1992     132000
# 2928         1389              2          1        1974     170000
# 2929         2000              3          2        1993     188000
#
# [2930 rows x 5 columns]

# %%
# Jumlah missing values
missing = df.loc[:,['Gr Liv Area', 'Bedroom AbvGr', 'Full Bath', 'Year Built', 'SalePrice']]
missing.isnull().sum()
# Out:
# Gr Liv Area      0
# Bedroom AbvGr    0
# Full Bath        0
# Year Built       0
# SalePrice        0
# dtype: int64

# %%
df['Year Built'] = df['Year Built'].astype(int)
df['Year Built'].dtypes
# Out:
# dtype('int64')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['Gr Liv Area', 'Bedroom AbvGr', 'Full Bath', 'Year Built']] = scaler.fit_transform(df[['Gr Liv Area', 'Bedroom AbvGr', 'Full Bath', 'Year Built']])
df[['Gr Liv Area', 'Bedroom AbvGr', 'Full Bath', 'Year Built']]
# Out:
#       Gr Liv Area  Bedroom AbvGr  Full Bath  Year Built
# 0        0.309265       0.176094  -1.024793   -0.375537
# 1       -1.194427      -1.032234  -1.024793   -0.342468
# 2       -0.337718       0.176094  -1.024793   -0.441674
# 3        1.207523       0.176094   0.784028   -0.110988
# 4        0.255844       0.176094   0.784028    0.848000
# ...           ...            ...        ...         ...
# 2925    -0.982723       0.176094  -1.024793    0.418109
# 2926    -1.182556      -1.032234  -1.024793    0.385040
# 2927    -1.048015       0.176094  -1.024793    0.682657
# 2928    -0.219006      -1.032234  -1.024793    0.087423
# 2929     0.989884       0.176094   0.784028    0.715726
#
# [2930 rows x 4 columns]

# %%
df.dtypes
# Out:
# Order               int64
# PID                 int64
# MS SubClass         int64
# MS Zoning          object
# Lot Frontage      float64
#                    ...
# Mo Sold             int64
# Yr Sold             int64
# Sale Type          object
# Sale Condition     object
# SalePrice           int64
# Length: 82, dtype: object

# %%
from sklearn.model_selection import train_test_split
x = df[['Gr Liv Area', 'Bedroom AbvGr', 'Full Bath', 'Year Built']]
y = df['SalePrice']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"MSE :{mse}, R2 Score :{r2}")
# Out:
# MSE :2402573307.636566, R2 Score :0.7003356477141082

# %%
coef = pd.DataFrame(model.coef_, x.columns, columns=['Coefficients'])
print(coef)
# Out:
#                Coefficients
# Gr Liv Area    57114.319446
# Bedroom AbvGr -15521.650620
# Full Bath      -2078.866817
# Year Built     30015.269535

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.scatter(y_test, y_pred)
ax.set(
    xlabel = 'Harga Aktual',
    ylabel = 'Harga Prediksi',
    title = 'Perbandingan Harga Aktual dengan Harga Prediksi'
)
plt.show()
